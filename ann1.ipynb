# %% [markdown]
# # Sigmoid Activation Function

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\kolek\appdata\local\programs\python\python310\lib\site-packages (3.8.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\kolek\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\kolek\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\kolek\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kolek\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\kolek\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kolek\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kolek\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kolek\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kolek\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: six>=1.5 in c:\users\kolek\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\kolek\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-10,10)
y=[]
for i in range(x.shape[0]):
    y.append((1/(1+np.exp(-x[i]))))
plt.plot(x,y,c='red')
plt.title("Sigmoid",c="green")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
    return 1/(1 + np.exp(-x))

def relu(x):
    return np.maximum(0,x)

def tanh(x):
    return np.tanh(x)

def softmax(x):
    exp_values = np.exp(x-np.max(x,axis=0,keepdims=True)) 
    return exp_values / np.sum(exp_values,axis=0,keepdims=True)

# %%
x=np.linspace(-5,5,100)

# %%
plt.figure(figsize=(8,8))
plt.subplot(2,2,1)
plt.plot(x,sigmoid(x),label='sigmoid')
plt.title("Sigmoid Activation Function")
plt.legend()
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot(x,relu(x),label='relu')
plt.title("relu Activation Function")
plt.legend()
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot(x,tanh(x),label='tanh')
plt.title("tanh Activation Function")
plt.legend()
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot(x,softmax(x),label='softmax')
plt.title("softmax Activation Function")
plt.legend()
plt.show()
